# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
fitness_df = pd.read_csv("../Resources/Wellbeing_and_lifestyle_data_Kaggle.csv")
fitness_df
# Out:
#           Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0            7/7/15               3            2               2            5
# 1            7/7/15               2            3               4            3
# 2            7/7/15               2            3               3            4
# 3            7/7/15               3            3              10            3
# 4            7/7/15               5            1               3            3
# ...             ...             ...          ...             ...          ...
# 15967  3/14/21 5:42               3            3               0            4
# 15968  3/14/21 6:30               3            3               6            8
# 15969  3/14/21 8:35               4            3               0           10
# 15970  3/14/21 8:43               1            1              10            8
# 15971  3/14/21 9:03               5            4               0            2
#
# ...

# %%
fitness_df = fitness_df.drop(10005)
fitness_df
# Out:
#           Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0            7/7/15               3            2               2            5
# 1            7/7/15               2            3               4            3
# 2            7/7/15               2            3               3            4
# 3            7/7/15               3            3              10            3
# 4            7/7/15               5            1               3            3
# ...             ...             ...          ...             ...          ...
# 15967  3/14/21 5:42               3            3               0            4
# 15968  3/14/21 6:30               3            3               6            8
# 15969  3/14/21 8:35               4            3               0           10
# 15970  3/14/21 8:43               1            1              10            8
# 15971  3/14/21 9:03               5            4               0            2
#
# ...

# %%
fitness_df['DAILY_STRESS'] = fitness_df['DAILY_STRESS'].astype('int64')

# %%
fitness_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15971 entries, 0 to 15971
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                15971 non-null  object
#  1   FRUITS_VEGGIES           15971 non-null  int64
#  2   DAILY_STRESS             15971 non-null  int64
#  3   PLACES_VISITED           15971 non-null  int64
#  4   CORE_CIRCLE              15971 non-null  int64
#  5   SUPPORTING_OTHERS        15971 non-null  int64
#  6   SOCIAL_NETWORK           15971 non-null  int64
#  7   ACHIEVEMENT              15971 non-null  int64
#  8   DONATION                 15971 non-null  int64
#  9   BMI_RANGE                15971 non-null  int64
#  10  TODO_COMPLETED           15971 non-null  int64
#  11  FLOW                     15971 non-null  int64
#  12  DAILY_STEPS              15971 non-null  int64
#  13  LIVE_VISION              15971 non-null  int64
# ...

# %%
age_group = fitness_df['AGE'].unique()
age_group
# Out:
# array(['36 to 50', '51 or more', '21 to 35', 'Less than 20'], dtype=object)

# %%
fitness_df2 = fitness_df.set_index(fitness_df['GENDER']).drop(columns=['Timestamp', 'BMI_RANGE','AGE'])
fitness_df2
# Out:
#         FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# GENDER
# Female               3             2               2            5
# Female               2             3               4            3
# Female               2             3               3            4
# Female               3             3              10            3
# Female               5             1               3            3
# ...                ...           ...             ...          ...
# Female               3             3               0            4
# Female               3             3               6            8
# Male                 4             3               0           10
# Female               1             1              10            8
# Female               5             4               0            2
#
#         SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  \
# GENDER
# Female                  0               5            2         0
# ...

# %%
# fitness_df.set_index('GENDER').plot(kind='bar', xlabel='GENDER', ylabel='SCALE', legend=None)
# plt.xlim(0, 2)
# plt.ylim(0,850)
# plt.grid()
# plt.show()

# %%
df_responses = fitness_df[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE', 
                           'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 
                           'TODO_COMPLETED', 'FLOW', 'DAILY_STEPS', 'LIVE_VISION', 'SLEEP_HOURS', 
                           'LOST_VACATION', 'DAILY_SHOUTING', 'SUFFICIENT_INCOME', 
                           'PERSONAL_AWARDS', 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION','GENDER']]

female_responses = df_responses.loc[df_responses["GENDER"]=="Female"]
female_responses = female_responses.drop('GENDER', axis=1)

male_responses = df_responses.loc[df_responses["GENDER"]=="Male"]
male_responses = male_responses.drop('GENDER', axis=1)

female_df_responses = female_responses.mean(axis=0)
male_df_responses = male_responses.mean(axis=0)
responses = pd.concat([female_df_responses, male_df_responses], axis=1, join="inner")
responses.index.name = 'Generalized Female to Male'
responses.reset_index(inplace=True)
responses = responses.rename(columns={0: 'Female', 1: 'Male'})
responses_parttwo = pd.melt(responses, id_vars=['Generalized Female to Male'], value_vars=['Female', 'Male'], var_name='Gender', value_name='Average Scoring')
plot = sns.barplot(data=responses_parttwo, x='Generalized Female to Male', y='Average Scoring', hue="Gender", palette="Set1")
plot.set_xticklabels(labels=['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE', 
                              'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 
                              'TODO_COMPLETED', 'FLOW', 'DAILY_STEPS', 'LIVE_VISION', 'SLEEP_HOURS', 
                              'LOST_VACATION', 'DAILY_SHOUTING', 'SUFFICIENT_INCOME', 
                              'PERSONAL_AWARDS', 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION'], rotation=90)
plt.show()

# %%
fitness_df = fitness_df.set_index(fitness_df['AGE']).drop(columns=['Timestamp', 'BMI_RANGE', 'AGE'])
fitness_df
# Out:
#             FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# AGE
# 36 to 50                 3             2               2            5
# 36 to 50                 2             3               4            3
# 36 to 50                 2             3               3            4
# 51 or more               3             3              10            3
# 51 or more               5             1               3            3
# ...                    ...           ...             ...          ...
# 51 or more               3             3               0            4
# 21 to 35                 3             3               6            8
# 21 to 35                 4             3               0           10
# 21 to 35                 1             1              10            8
# 21 to 35                 5             4               0            2
#
#             SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  \
# AGE
# ...

# %%
# <20
# 21-35
# 36-50
# >51
# ['36 to 50', '51 or more', '21 to 35', 'Less than 20']

# %%
age_bins = {'Less than 20': 20, '21 to 35': 21, '36 to 50': 36, '51 or more': 51}
fitness_df.index = fitness_df.index.map(age_bins)
fitness_df
# Out:
#      FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# AGE
# 36                3             2               2            5
# 36                2             3               4            3
# 36                2             3               3            4
# 51                3             3              10            3
# 51                5             1               3            3
# ..              ...           ...             ...          ...
# 51                3             3               0            4
# 21                3             3               6            8
# 21                4             3               0           10
# 21                1             1              10            8
# 21                5             4               0            2
#
#      SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  TODO_COMPLETED  \
# AGE
# 36                   0               5            2         0               6
# ...

# %%
gender_float = {'Female': 1, 'Male': 2}
fitness_df['GENDER'] = fitness_df['GENDER'].map(gender_float)
fitness_df
# Out:
#      FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# AGE
# 36                3             2               2            5
# 36                2             3               4            3
# 36                2             3               3            4
# 51                3             3              10            3
# 51                5             1               3            3
# ..              ...           ...             ...          ...
# 51                3             3               0            4
# 21                3             3               6            8
# 21                4             3               0           10
# 21                1             1              10            8
# 21                5             4               0            2
#
#      SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  TODO_COMPLETED  \
# AGE
# 36                   0               5            2         0               6
# ...

# %%
fitness_df
# Out:
#      FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# AGE
# 36                3             2               2            5
# 36                2             3               4            3
# 36                2             3               3            4
# 51                3             3              10            3
# 51                5             1               3            3
# ..              ...           ...             ...          ...
# 51                3             3               0            4
# 21                3             3               6            8
# 21                4             3               0           10
# 21                1             1              10            8
# 21                5             4               0            2
#
#      SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  TODO_COMPLETED  \
# AGE
# 36                   0               5            2         0               6
# ...

# %%
# You still need to clean up graph two, adjust the age bracket 
# labels, and see if you can segment this by response.

# %%
# Is there an inverse relationship between daily_shouting and 
# time_for_passion? (Meaning, if a person has time_for_passion, 
# is their daily_shouting a lower number?)

# %%
shouting_passion = sns.scatterplot(x="DAILY_SHOUTING", y="WORK_LIFE_BALANCE_SCORE", data=fitness_df)
shouting_passion.set_title("Daily Shouting Measured Against Work-Life Balance")
shouting_passion.set_xlabel("Daily Shouting Score")
shouting_passion.set_ylabel("Work-Life Balance Score")
# plt.xlim(0, 10)
# plt.ylim(0, 10)
sns.lmplot(x="DAILY_SHOUTING", y="WORK_LIFE_BALANCE_SCORE", data=fitness_df)
# Out:
# /Users/raphael/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
shouting_passion = sns.scatterplot(x="TIME_FOR_PASSION", y="WORK_LIFE_BALANCE_SCORE", data=fitness_df)
shouting_passion.set_title("Time for Passion Measured Against Work-Life Balance")
shouting_passion.set_xlabel("Time for Passion Score")
shouting_passion.set_ylabel("Work-Life Balance Score")
# plt.xlim(0, 10)
# plt.ylim(0, 10)
sns.lmplot(x="TIME_FOR_PASSION", y="WORK_LIFE_BALANCE_SCORE", data=fitness_df)
# Out:
# /Users/raphael/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(12, 8))
plt.boxplot([fitness_df.loc[fitness_df['PLACES_VISITED'] == i, 'DONATION'] 
             for i in sorted(fitness_df['PLACES_VISITED'].unique())])
plt.title('Donation Score in Relation to the Amount of Places Visited')
plt.xlabel('Number of Places Visited')
plt.ylabel('Donation Score')
plt.xticks(ticks=range(1, len(fitness_df['PLACES_VISITED'].unique()) + 1), labels=sorted(fitness_df['PLACES_VISITED'].unique()))
plt.grid(True)
plt.show()

# %%
fitness_df = fitness_df[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE', 
                              'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 
                              'TODO_COMPLETED', 'FLOW', 'DAILY_STEPS', 'LIVE_VISION', 'SLEEP_HOURS', 
                              'LOST_VACATION', 'DAILY_SHOUTING', 'SUFFICIENT_INCOME', 
                              'PERSONAL_AWARDS', 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION', 'WORK_LIFE_BALANCE_SCORE']]

fitness_df_correlation = fitness_df.corr()
round(fitness_df_correlation)

sns.heatmap(fitness_df_correlation, cmap="YlGnBu", annot=True, fmt="0.0f")
plt.show()
